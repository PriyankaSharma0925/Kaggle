# %% [markdown]
# <a href="https://www.kaggle.com/code/priyankamukulsharma/regelar-expressionfornlp?scriptVersionId=95419415" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # We will learn how to use RegularExpression. Learning regular expression will help us in solving many of the NLP problems as it is extensively used in NLP.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %config Completer.use_jedi = False

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **https://regex101.com/ is a nice app where you can verify your reg ex before using then in code**. Here I am using reg_ex for chatbot usecase and information extraction usecase.

# %%
text1="you ask lot of questions 1234567089,abc@xyz.com,9087654321 and order#9876543"
text2="no here it is : order 987651143 (123)-456-7895,abcA_23@xyz.us,(1233)-345-0987"
text3="yes please phone:9934509876 and email is abc@xyx.in and other phone number is (678)-345-9876 and no alternate email id with order number 9870006543"

# %%
pattern='\d{10}'
re.findall(pattern,text1)
# Out:
# ['1234567089', '9087654321']

# %%
#to check this sequence (123)-456-7895 we will use the below pattern
pattern2='\(\d{3}\)-\d{3}-\d{4}'
re.findall(pattern2,text2)
# Out:
# ['(123)-456-7895']

# %%
# pipe symbole is used for OR. this pattern or other pattern should match
pattern3='\d{10}|\(\d{3}\)-\d{3}-\d{4}'
re.findall(pattern3,text3)

#matches
# Out:
# ['9934509876', '(678)-345-9876', '9870006543']

# %% [markdown]
# # Basic email regular expression

# %%
pattern4='[a-zA-z0-9_\.\-]+@[a-zA-Z0-9]+\.[a-z]{2,3}' # here we are saying before @ there could be 1 or more than 1 occurance of small or capital alphabets ,0-9 digits or_,-0r . and 
re.findall(pattern4,text1)                            # after @ there can be one or more occurence of small or capital alphabets and after . minimum of 2 or maximum of 3 small alphabets.
# Out:
# ['abc@xyz.com']

# %%
re.findall(pattern4,text2)
# Out:
# ['abcA_23@xyz.us']

# %%
re.findall(pattern4,text3)
# Out:
# ['abc@xyx.in']

# %% [markdown]
# # Extracting order number

# %%
pattern5='order[^\d]*([0-9]+)' # here we are saying match anything after order that is not digit after that it should be one or more digits

# %%
re.findall(pattern5,text1)
# Out:
# ['9876543']

# %%
re.findall(pattern5,text2)
# Out:
# ['987651143']

# %%
re.findall(pattern5,text3)
# Out:
# ['9870006543']

# %% [markdown]
# # Lets do the information retreival from Wikipedia

# %%
text='''Elon Reeve Musk FRS is an entrepreneur, investor, and business magnate. He is the founder, CEO, and chief engineer at SpaceX; angel investor, CEO, and Product Architect of Tesla, Inc.; founder of The Boring Company; and co-founder of Neuralink and OpenAI. Wikipedia
Born: 28 June 1971 (age 50 years), Pretoria, South Africa
Net worth: 25,510 crores USD (2022) Forbes
Spouse: Talulah Riley (m. 2013–2016), Talulah Riley (m. 2010–2012), Justine Musk (m. 2000–2008)
Children: X Æ A-Xii, Nevada Alexander Musk, Damian Musk, MORE
Education: University of Pennsylvania (1992–1997), MORE
Books: Elon Musk'''

# %% [markdown]
# **Extracting the age fron the text.**

# %%
pattern6='age (\d+)' # here out of the result we are extracting only the digit part.

# %%
re.findall(pattern6,text)
# Out:
# ['50']

# %% [markdown]
# **Extracting the birth place.**

# %%
pattern7='Born:(.*)\(' # Here . implies any character and start means zero or more occurances.
re.findall(pattern7,text)
# Out:
# [' 28 June 1971 ']

# %% [markdown]
# **Trying to get the birth place.**

# %%
pattern8='\(age.*\n'
matches=re.findall(pattern8,text)
matches[0].strip()
# Out:
# '(age 50 years), Pretoria, South Africa'

# %% [markdown]
# # Credits: https://www.youtube.com/watch?v=lK9gx4q_vfI
